# %%
# importing all libraries needed
import numpy as np
import pandas as pd
import os

# %%
df =  pd.read_csv('final_cleaned.csv')

# %%
apt_no_minus_apt_first = np.empty(len(df))
df['apt_no-apt_no_1'] = apt_no_minus_apt_first
apt_no_minus_apt_last = np.empty(len(df))
df['apt_no_minus_apt_last'] = apt_no_minus_apt_last

# %%
df
# Out:
#        Unnamed: 0  Patient_ID        Date      Time     Location  QIDS  GAD7  \
# 0               1  AACH000001    7/2/2018  09:46:03  Raleigh, NC   NaN   NaN
# 1               2  AACH000001   29/1/2018  09:07:20  Raleigh, NC  14.0  16.0
# 2               3  AACH000001   16/2/2018  09:18:35  Raleigh, NC   NaN   NaN
# 3               4  AACH000001    2/2/2018  09:58:15  Raleigh, NC   NaN   NaN
# 4               5  AACH000001    5/2/2018  09:39:12  Raleigh, NC   NaN   NaN
# ...           ...         ...         ...       ...          ...   ...   ...
# 22677       22678  ZWCL000001   11/7/2018  11:48:10  Raleigh, NC   0.0   0.0
# 22678       22679  ZWCL000001  22/11/2019  14:17:24  Raleigh, NC   3.0   6.0
# 22679       22680  ZWCL000001   26/6/2019  10:51:11  Raleigh, NC   4.0   0.0
# 22680       22681  ZWCL000001   14/5/2018  10:13:38  Raleigh, NC   9.0   4.0
# 22681       22682  ZWCL000001   20/8/2018  14:37:42  Raleigh, NC   1.0   0.0
#
# ...

# %%
df['apt_no_minus_apt_last'][0]

# %%
for i  in range(0, len(df)):
    df['apt_no-apt_no_1'][i] = pd.to_datetime(df.loc[(df['Patient_ID'] == df['Patient_ID'][i]) & (df['Apt_no'] == df['Apt_no'][i] ) , 'Date'].iloc[0]) - pd.to_datetime(df.loc[(df['Patient_ID'] == df['Patient_ID'][i]) & (df['Apt_no'] == 1) , 'Date'].iloc[0])
    
#     a = df.loc[(df['Patient_ID'] == df['Patient_ID'][i]), 'count'].iloc[0]
    
#     if a > 1:
#         df['apt_no_minus_apt_last'][i] = pd.to_datetime(df.loc[(df['Patient_ID'] == df['Patient_ID'][i]) & (df['Apt_no'] == df['Apt_no'][i]) , 'Date'].iloc[0]) - pd.to_datetime(df.loc[(df['Patient_ID'] == df['Patient_ID'][i]) & (df['Apt_no'] == df['Apt_no'][i] - 1) , 'Date'].iloc[0])
    
#     else:
#         df['apt_no_minus_apt_last'][i] = pd.to_datetime(df.loc[(df['Patient_ID'] == df['Patient_ID'][i]) & (df['Apt_no'] == df['Apt_no'][i]) , 'Date'].iloc[0]) - pd.to_datetime(df.loc[(df['Patient_ID'] == df['Patient_ID'][i]) & (df['Apt_no'] == df['Apt_no'][i]) , 'Date'].iloc[0])
# Out:
# C:\Users\intri\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
for i  in range(0, len(last_ID)): 
    source['days since first'][i] = last[i]
    source['days since last'][i] = prelast[i]

# %%
df.to_csv('final_cleaned_grecia.csv', index=False)

# %%
type(prelast)
